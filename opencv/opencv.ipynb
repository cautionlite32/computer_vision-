# %%
import os
import cv2

# %%
image_path = "C:/Users/pawan/OneDrive/Pictures/ram.jpg"

# %%
img = cv2.imread(image_path)

# %%
cv2.imwrite(image_path ,img)
# Out:
# True

# %%
cv2.imshow('haa', img)
#cv2.waitKey(0)

# %% [markdown]
# # video

# %%
video_path = "C:/Users/pawan/Downloads/Untitled video - Made with Clipchamp.mp4"

# %%
video = cv2.VideoCapture(video_path)

# %%
ret = True
while ret:
    ret, frame = video.read()
    if ret:
        cv2.imshow('frame', frame)
        cv2.waitKey(40)

# %%
video.release()
cv2.destroyAllWindows()

# %% [markdown]
# # WEBCAM

# %%
webcam = cv2.VideoCapture(0)

# %%
while True:
    ret, frame = webcam.read()
    cv2.imshow('frame', frame)
    if cv2.waitKey(40) & 0xFF == ord('q'):
        break

# %%
webcam.release()
cv2.destroyAllWindows('q')

# %% [markdown]
# # RESIZE AN IMAGE

# %%
img = cv2.imread("C:/Users/pawan/Downloads/IMG_20240515_213110.jpg")
print(img.shape)
# Out:
# (9280, 6944, 3)

# %%
resiexe = cv2.resize(img, (640, 480))

# %%
print(resiexe.shape)
# Out:
# (480, 640, 3)

# %%
cv2.imshow('img', resiexe)
cv2.waitKey(10)
# Out:
# -1

# %%
# CROP

# %%
 crop_img = img[100:400, 200:600]

# %%
cv2.imshow('çrop_img', crop_img)

# %% [markdown]
#  # COLOR SPACES

# %%
import os
import cv2

# %%
img = cv2.imread("C:/Users/pawan/OneDrive/Pictures/Screenshots/allhailthetiger/Screenshot 2023-11-21 172524.png")

# %%
imb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imp = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imt = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
cv2.imshow('img', img)
cv2.imshow('imb', imb)
cv2.imshow('imp', imp)
cv2.imshow('imt', imt)
cv2.waitKey(0)

# %% [markdown]
# color space conversion (https://docs.opencv.org/4.x/d8/d01/group__imgproc__color__conversions.html

# %% [markdown]
# # BLURRING

# %%
import cv2
import os

# %%
img = cv2.imread("C:/Users/pawan/OneDrive/Pictures/Screenshots/allhailthetiger/Screenshot 2024-02-05 212139 - Copy.png")

# %%
k = 7
img_b = cv2.blur(img, (k,k))
img_G = cv2.GaussianBlur(img, (k,k), 0)
img_m = cv2.medianBlur(img, k)
img_bi = cv2.bilateralFilter(img,k,75,75)

# %%
cv2.imshow('img', img)
cv2.imshow('img_b', img_b)
cv2.imshow('img_G', img_G)
cv2.imshow('img_m', img_m)
cv2.imshow('img_bi', img_bi)


cv2.waitKey(0)

# %% [markdown]
# here the blur samples and their examples
# https://docs.opencv.org/4.x/d4/d13/tutorial_py_filtering.html

# %% [markdown]
# # IMAGE THRESHOLDING

# %%
import cv2

# %%
img = cv2.imread("C:/Users/pawan/OneDrive/Pictures/Screenshots/allhailthetiger/Screenshot 2024-02-20 194027 - Copy.png")

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(img_gray, 80, 255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY_INV) 
ret, thresh3 = cv2.threshold(img, 120, 255, cv2.THRESH_TRUNC) 
ret, thresh4 = cv2.threshold(img, 120, 255, cv2.THRESH_TOZERO) 
ret, thresh5 = cv2.threshold(img, 120, 255, cv2.THRESH_TOZERO_INV) 
  
# here the pixel values below 80 are set to 0 and above are set to 255

# %%
cv2.imshow('img',img)
cv2.imshow('thresh', thresh)
cv2.imshow('thresh2', thresh2)
cv2.imshow('thresh3', thresh3)
cv2.imshow('thresh4', thresh4)
cv2.imshow('thresh5', thresh5)
cv2.waitKey(0)

# %%
thresh = cv2.blur(thresh, (10, 10))
ret, thresh = cv2.threshold(img_gray, 80, 255, cv2.THRESH_BINARY)

# %%
cv2.imshow('thresh', thresh)
cv2.waitKey(0)

# %%
cv2.adaptiveThreshold(img_gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 21 ,30)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
cv2.imshow('thresh', thresh)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # EDGE DETECTION

# %%
import cv2
import os
import numpy as np

# %%
img = cv2.imread("C:/Users/pawan/OneDrive/Pictures/Screenshots/allhailthetiger/Screenshot 2024-01-21 214834.png")

# %%
edge = cv2.Canny(img, 90, 20) #thrsholds of 1st and 2nd hysteresis process
edge_d = cv2.dilate(edge, np.ones((5,5), dtype=np.int8))# used to thicken the edges of objects in an image 
edge_dt = cv2.erode(edge_d, np.ones((7,5), dtype=np.int8))# performs reverse operations of dilate

# %%
cv2.imshow('img', img)
cv2.imshow('egde', edge)
cv2.imshow('egde_d', edge_d)
cv2.imshow('egde_dt', edge_dt)
cv2.waitKey(0)

# %% [markdown]
# # DRAWING IN OPENCV

# %%
import os
import cv2
import numpy as np

# %%
img = cv2.imread("C:/Users/pawan/OneDrive/Pictures/Screenshots/allhailthetiger/Screenshot 2024-02-12 194902.png")

# %%
cv2.line(img, (0,289), (567, 998), (0, 255, 0), 4) #fist 2 are coordinates and the last one is color with intensity 
cv2.rectangle(img, (110,220), (330,200), (0, 0, 225), 5)
cv2.circle(img, (0,200), 200, (255, 0, 0), 5)
cv2.putText(img, 'all hail tiger',(220,200),cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 0, 0), 5)
# Out:
# array([[[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [  5,   0,   0],
#         [  5,   0,   0],
#         [  5,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 23,  23,  23],
#         [ 23,  23,  23],
#         [ 23,  23,  23]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 44, 152, 229],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        ...,
#
#        [[  5,   0,   0],
#         [ 25, 121, 221],
#         [ 25, 121, 221],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[  5,   0,   0],
#         [ 25, 121, 221],
#         [ 25, 121, 221],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[  5,   0,   0],
#         [ 23,  23,  23],
#         [ 23,  23,  23],
# ...

# %%
cv2.imshow('img', img)
cv2.waitKey(0)
# Out:
# -1

# %%
print(img.shape)
# Out:
# (425, 424, 3)

# %% [markdown]
# # CONTOURS

# %% [raw]
# In OpenCV, counters are defined as a curve joining all the continuous points (along the boundary), having same color or intensity. The contours are a useful tool for shape analysis and object detection and recognition
#
# Used for wide applications, obj det, shape analysis, obj track, findcontours()

# %%
import os 
import cv2
import numpy as np

# %%
img = cv2.imread("C:/Users/pawan/OneDrive/Pictures/Screenshots/Screenshot 2024-06-12 121605.png")

# %%
img_b = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
reg, thresh = cv2.threshold(img_b, 120, 255, cv2.THRESH_BINARY_INV)

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
print(cv2.contourArea(cut))
# Out:
# 143.0

# %%
for cut in contours:
    if(cv2.contourArea(cut)) > 100:
        #cv2.drawContours(thresh, cut, -1,(0, 255, 0), 1)
        x1, y1, w, h = cv2.boundingRect(cut) # bounding boxes around images 
        cv2.rectangle(img, (x1,y1), (x1 + w, y1 + h), (0, 255, 0), 2)

# %%
cv2.imshow('rrr', img)
cv2.imshow('r', img_b)
cv2.imshow('rr', thresh)

cv2.waitKey(0)
# Out:
# -1

# %% [raw]
# parameters included in contiurs are
# 1.source image
# 2.contour retrieval mode
# 3.contour approximation mode

# %% [raw]
# The code snippet `contours, hierarchy = cv2.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)` is a function call from the OpenCV library, which is widely used for computer vision tasks. Let's break down what each part of this code does and its significance:
#
# ### Breakdown of the Code Snippet
#
# 1. **`cv2.findContours`**:
#    - This function is used to detect the contours in an image. Contours can be thought of as a curve joining all the continuous points along a boundary having the same color or intensity. They are useful in shape analysis, object detection, and image segmentation.
#
# 2. **`thresh`**:
#    - This is the input image in which contours are to be found. It should be a binary image, where the background is typically black (0), and the objects whose contours need to be found are white (255). The `thresh` variable usually comes from a previous thresholding operation like `cv2.threshold` or `cv2.adaptiveThreshold`.
#
# 3. **`cv.RETR_TREE`**:
#    - This is a mode of contour retrieval. The `cv.RETR_TREE` flag retrieves all of the contours and reconstructs a full hierarchy of nested contours. This hierarchy can be very useful for understanding the relationship between contours, such as determining which contours are nested within others.
#
# 4. **`cv.CHAIN_APPROX_SIMPLE`**:
#    - This is a contour approximation method. The `cv.CHAIN_APPROX_SIMPLE` flag compresses horizontal, vertical, and diagonal segments and leaves only their end points. For example, a straight contour will be encoded with only its two end points. This reduces the amount of memory required to store the contour information.
#
# 5. **`contours`**:
#    - This is the output list of all the detected contours. Each contour is stored as a vector of points (i.e., a list of (x, y) coordinates). These contours can be used for various applications such as shape analysis or object detection.
#
# 6. **`hierarchy`**:
#    - This is an optional output containing information about the image topology. It's a vector of four values for each contour:
#      - `hierarchy[i][0]`: The next contour at the same hierarchical level.
#      - `hierarchy[i][1]`: The previous contour at the same hierarchical level.
#      - `hierarchy[i][2]`: The first child contour.
#      - `hierarchy[i][3]`: The parent contour.
#    - This data structure is useful when you want to analyze the nested relationships between contours.
#
# ### Detailed Explanation of Each Component
#
# 1. **Input Image (thresh)**:
#    - Before calling `cv2.findContours`, you need a binary image (often created using thresholding). The `thresh` image is where white regions represent the objects of interest, and black regions represent the background.
#
# 2. **Contour Retrieval Mode (cv.RETR_TREE)**:
#    - `cv.RETR_TREE` retrieves all contours and creates a full hierarchy. Other modes include:
#      - `cv.RETR_EXTERNAL`: Retrieves only the external contours.
#      - `cv.RETR_LIST`: Retrieves all contours but does not create any parent-child relationship.
#      - `cv.RETR_CCOMP`: Retrieves all contours and organizes them into a two-level hierarchy: outer contours and holes inside them.
#
# 3. **Contour Approximation Method (cv.CHAIN_APPROX_SIMPLE)**:
#    - Simplifies the contours by removing all redundant points and compressing the contour, thereby saving memory and processing time.
#    - Another method is `cv.CHAIN_APPROX_NONE`, which stores all contour points without any compression, which can be more detailed but also more memory-intensive.
#
# 4. **Output (contours)**:
#    - This list contains the contours detected in the binary image. Each contour is an array of points.
#    - Example: If a contour outlines a rectangle, it would contain four points, one for each corner of the rectangle.
#
# 5. **Output (hierarchy)**:
#    - This array describes the relationship between contours. It is particularly useful for nested contours, like detecting holes inside objects.
#
# ### Example Usage
#
# Here’s an example to illustrate how you might use `cv2.findContours` in a complete program:
#
# ```python
# import cv2
# import numpy as np
#
# # Read the image
# image = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)
#
# # Apply binary thresholding
# ret, thresh = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
#
# # Find contours and hierarchy
# contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#
# # Draw contours on the original image
# image_contours = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
# cv2.drawContours(image_contours, contours, -1, (0, 255, 0), 2)
#
# # Show the image with contours
# cv2.imshow('Contours', image_contours)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# ```
#
# In this example, contours are detected and drawn on the original image, highlighting the detected shapes.
#
# ### Practical Applications
#
# - **Object Detection**: Contours can be used to detect and isolate specific objects within an image.
# - **Shape Analysis**: You can analyze the shapes of objects to differentiate between them based on their contours.
# - **Image Segmentation**: Contours help in segmenting images into different parts, useful for various image processing tasks.
#
# Understanding how to use `cv2.findContours` and interpret its outputs is fundamental for many image analysis tasks in computer vision.

# %% [markdown]
# # COLOR DETECTION

# %%
import numpy as np
import cv2
from PIL import Image

# %%
def get_limits(color):
    c = np.uint8([[color]]) # enter bgr converts to hsv
    hsvC = cv2.cvtColor(c, cv2.COLOR_BGR2HSV)
    lowerlimit = hsvC[0][0][0] - 10, 100, 100
    upperlimit = hsvC[0][0][0] + 10, 255, 255

    lowerlimit = np.array(lowerlimit, dtype = np.uint8)
    upperlimit = np.array(upperlimit, dtype = np.uint8)

    return lowerlimit, upperlimit

# %% [raw]
# HSB (Hue, Saturation, Brightness) is a color space used in image processing and computer graphics to represent colors in a way that aligns more closely with human perception of colors than the traditional RGB (Red, Green, Blue) model. Understanding the HSB color space can be very useful for tasks that involve color manipulation and analysis.
#
# ### Components of HSB Color Space
#
# 1. **Hue (H)**:
#     - **Definition**: Hue represents the type of color or the wavelength of the color. It defines the color itself, such as red, blue, green, etc.
#     - **Range**: Typically measured in degrees on a color wheel from 0° to 360°.
#       - 0° represents red.
#       - 120° represents green.
#       - 240° represents blue.
#     - **Interpretation**: Hue determines the base pigment of the color and differentiates between colors like red, green, and blue.
#
# 2. **Saturation (S)**:
#     - **Definition**: Saturation measures the intensity or purity of the color. It describes the amount of gray in the color, with lower saturation resulting in a more washed-out color and higher saturation producing a more vivid color.
#     - **Range**: Typically expressed as a percentage from 0% to 100%.
#       - 0% saturation results in a shade of gray.
#       - 100% saturation means the color is fully pure without any gray.
#     - **Interpretation**: Saturation affects how "colorful" or "muted" a color appears.
#
# 3. **Brightness (B)**:
#     - **Definition**: Brightness refers to how light or dark the color is. It indicates the amount of light emitted or reflected by the color.
#     - **Range**: Typically expressed as a percentage from 0% to 100%.
#       - 0% brightness is completely black.
#       - 100% brightness is the brightest version of the color.
#     - **Interpretation**: Brightness determines the lightness or darkness of the color.
#
# ### Comparison to Other Color Spaces
#
# - **RGB**: Represents colors based on combinations of Red, Green, and Blue light intensities. It’s widely used for digital displays and image sensors but isn’t as intuitive for human perception and manipulation of color.
# - **HSV (Hue, Saturation, Value)**: Similar to HSB, but here, Value often means brightness, making it synonymous with HSB in many contexts.
# - **HSL (Hue, Saturation, Lightness)**: Another similar model where Lightness represents a different way of defining brightness. HSL’s lightness is the average of the maximum and minimum values of RGB, leading to differences in how colors are represented compared to HSB/HSV.
#
# ### Practical Applications of HSB
#
# 1. **Color Manipulation**:
#     - Easier to adjust the hue to change the color while maintaining the same level of brightness and saturation.
#     - Useful for applications requiring precise control over color properties, like digital painting, photo editing, and graphic design.
#
# 2. **Image Segmentation**:
#     - HSB allows for easier segmentation based on color properties. For example, isolating specific hues or ranges of saturation can help in identifying objects or regions of interest in an image.
#
# 3. **Lighting Adjustments**:
#     - Adjusting brightness without affecting the hue or saturation can simulate lighting changes, useful in video production and photography.
#
# 4. **User Interface Design**:
#     - Color pickers in design software often use HSB because it allows users to intuitively select and modify colors.
#
# ### Conversion Between Color Spaces
#
# To convert from RGB to HSB, you can use the following process:
#
# 1. **Normalize RGB Values**:
#    - Convert RGB values from a range of 0-255 to a range of 0-1 by dividing by 255.
#
# 2. **Calculate Brightness**:
#    - Brightness \( B \) is the maximum of the normalized R, G, and B values.
#
# 3. **Calculate Saturation**:
#    - Saturation \( S \) is defined as:
#      - If \( B = 0 \), then \( S = 0 \).
#      - Otherwise, \( S = \frac{B - \text{min}(R, G, B)}{B} \).
#
# 4. **Calculate Hue**:
#    - Calculate the difference between the maximum and minimum values of the normalized R, G, and B.
#    - Depending on which value is the maximum, determine the hue angle:
#      - If \( \text{max} = R \), \( H = 60 \times \left( \frac{G - B}{\Delta} \right) \).
#      - If \( \text{max} = G \), \( H = 60 \times \left( 2 + \frac{B - R}{\Delta} \right) \).
#      - If \( \text{max} = B \), \( H = 60 \times \left( 4 + \frac{R - G}{\Delta} \right) \).
#    - Ensure \( H \) is between 0° and 360° by adding 360° if necessary.
#
# ### Code Example in Python
#
# Here is a Python example using OpenCV to convert an image from RGB to HSB:
#
# ```python
# import cv2
#
# # Load an image
# image = cv2.imread('image.jpg')
#
# # Convert from BGR (OpenCV default) to RGB
# image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#
# # Convert RGB to HSB
# image_hsb = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2HSV)
#
# # Split the HSB channels
# hue, saturation, brightness = cv2.split(image_hsb)
#
# # Display the individual channels
# cv2.imshow('Hue', hue)
# cv2.imshow('Saturation', saturation)
# cv2.imshow('Brightness', brightness)
#
# # Wait until a key is pressed and close all windows
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# ```
#
# ### Summary
#
# The HSB color space is a powerful tool in image processing, providing an intuitive way to manipulate and analyze colors. It separates the color information into hue, saturation, and brightness, making it particularly useful for tasks that require color adjustments and analysis in a manner more aligned with human visual perception.

# %%
# HUE - calor change, saturation - intensity/ thickness of respective color
blue = [255, 0, 0] # blue in BGR colorspace 
cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read()
    hsvImage = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    lowerLimit, upperLimit = get_limits(color=blue)
    mask = cv2.inRange(hsvImage,lowerLimit, upperLimit)
    mask_ = Image.fromarray(mask)
    bbox = mask_.getbbox()
    if bbox is not None:
        x1, y1, x2, y2 = bbox
        frame = cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 5)
    print(bbox)
    cv2.imshow('frame', mask)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# None
# None
# None
# None
# None
# None
# (583, 345, 584, 346)
# None
# (583, 345, 587, 346)
# (579, 342, 580, 344)
# (579, 343, 586, 346)
# (579, 332, 592, 346)
# None
# (579, 343, 587, 346)
# (579, 315, 591, 346)
# (584, 345, 588, 346)
# (584, 345, 587, 346)
# (579, 336, 586, 346)
# (579, 336, 587, 346)
# (584, 345, 589, 346)
# None
# (584, 332, 592, 346)
# (584, 345, 585, 346)
# (579, 336, 587, 346)
# (584, 345, 586, 346)
# None
# (579, 337, 587, 346)
# None
# (587, 345, 589, 346)
# (579, 337, 580, 338)
# (583, 345, 588, 346)
# (579, 336, 586, 346)
# (584, 345, 587, 346)
# None
# None
# (583, 345, 584, 346)
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# (579, 337, 580, 338)
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %% [markdown]
# # FACE ANONYMIZER

# %%
import cv2
import numpy as np
import mediapipe as mp

# %%
img_pt = "C:/Users/pawan/OneDrive/Pictures/Screenshots/img.jpg"

# %%
img = cv2.imread(img_pt)

# %%
H, W, _ = img.shape

# %%
mp_face_det = mp.solutions.face_detection

# %%
with mp_face_det.FaceDetection(min_detection_confidence=0.5, model_selection=0) as face_detection:
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ot = face_detection.process(img_rgb)
    if ot.detections is not None:
        for det in ot.detections:
            loc_dt = det.location_data
            bbox = loc_dt.relative_bounding_box
            x1, y1, w, h = bbox.xmin, bbox.ymin, bbox.width, bbox.height
            x1 = int(x1 * W)
            y1 = int(x1 * H)
            w = int(w * W)
            h = int(h * H)
            # blur the image 
            H, W = img.shape[:2]
            if x1 < 0 or y1 < 0 or x1 + w > W or y1 + h > H:
                print("ROI coordinates are out of bounds.")
            else:
                img[y1:y1 + h, x1:x1 + w, :] = cv2.blur(img[y1:y1 + h, x1:x1 + w, :], (15,15))

    cv2.imshow('img', img)
    cv2.waitKey(0)
# Out:
# ROI coordinates are out of bounds.

# %%
import argparse
import cv2
import mediapipe as mp

# %%
import os
import argparse

import cv2
import mediapipe as mp


def process_img(img, face_detection):

    H, W, _ = img.shape

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    out = face_detection.process(img_rgb)

    if out.detections is not None:
        for detection in out.detections:
            location_data = detection.location_data
            bbox = location_data.relative_bounding_box

            x1, y1, w, h = bbox.xmin, bbox.ymin, bbox.width, bbox.height

            x1 = int(x1 * W)
            y1 = int(y1 * H)
            w = int(w * W)
            h = int(h * H)

            # print(x1, y1, w, h)

            # blur faces
            img[y1:y1 + h, x1:x1 + w, :] = cv2.blur(img[y1:y1 + h, x1:x1 + w, :], (30, 30))

    return img


args = argparse.ArgumentParser()

args.add_argument("--mode", default='webcam')
args.add_argument("--filePath", default=None)

args = args.parse_args()


output_dir = './output'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# detect faces
mp_face_detection = mp.solutions.face_detection

with mp_face_detection.FaceDetection(model_selection=0, min_detection_confidence=0.5) as face_detection:

    if args.mode in ["image"]:
        # read image
        img = cv2.imread(args.filePath)

        img = process_img(img, face_detection)

        # save image
        cv2.imwrite(os.path.join(output_dir, 'output.png'), img)

    elif args.mode in ['video']:

        cap = cv2.VideoCapture(args.filePath)
        ret, frame = cap.read()

        output_video = cv2.VideoWriter(os.path.join(output_dir, 'output.mp4'),
                                       cv2.VideoWriter_fourcc(*'MP4V'),
                                       25,
                                       (frame.shape[1], frame.shape[0]))

        while ret:

            frame = process_img(frame, face_detection)

            output_video.write(frame)

            ret, frame = cap.read()

        cap.release()
        output_video.release()

    elif args.mode in ['webcam']:
        cap = cv2.VideoCapture(2)

        ret, frame = cap.read()
        while ret:
            frame = process_img(frame, face_detection)

            cv2.imshow('frame', frame)
            cv2.waitKey(25)

            ret, frame = cap.read()

        cap.release()
# Out:
# usage: ipykernel_launcher.py [-h] [--mode MODE] [--filePath FILEPATH]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\pawan\AppData\Roaming\jupyter\runtime\kernel-f3378342-8ca3-4871-a9bf-dffba26ba548.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
